# %% [markdown]
# # For Monte Carlo simulations with varying values of dy
# ##

# %%
import os

def run(str):
    os.system(str)

# %%
os.chdir("/home/zes5027/GIT/fitpack")
run("source setup.bash")

# %%
jamit = "jam3d -t 1 -p inputs/"
dy_1 = "upol_hermes_alexei.py"
dy_2 = "upol_hermes_alexei2.py"
dy_225 = "upol_hermes_alexei225.py"
dy_25 = "upol_hermes_alexei25.py"
dy_275 = "upol_hermes_alexei275.py"
dy_3 = "upol_hermes_alexei3.py"
dy_35 = "upol_hermes_alexei35.py"

concat = "mcproc ."
filter = "mcoroc -c 0.001"

# %%
#print(os.getcwd())
os.chdir("/home/zes5027/GIT/psu_project_2018")
print(os.getcwd())
# Out:
# /home/zes5027/GIT/psu_project_2018

# %%
run(jamit + dy_1)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
run("jam3d -t 1 -p inputs/upol_hermes_alexei2.py")

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
run("jam3d -t 1 -p inputs/upol_hermes_alexei225.py")

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
run("jam3d -t 1 -p inputs/upol_hermes_alexei25.py")

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
run("jam3d -t 1 -p inputs/upol_hermes_alexei275.py")

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
run("jam3d -t 1 -p inputs/upol_hermes_alexei3.py")

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
run("jam3d -t 1 -p inputs/upol_hermes_alexei325.py")

# %% [markdown]
# ![image.png](attachment:image.png)
